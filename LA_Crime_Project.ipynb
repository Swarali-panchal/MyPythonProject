# %% [markdown]
# ## Read data

# %%
import pandas as pd
import matplotlib.pyplot as plt
crime = pd.read_csv('Data for python course/Crime_Data_from_2020_to_Present.csv')

# %%
crime.head()
# Out:
#    division_number date_reported        date_occurred  area    area_name  \
# 0         10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1        190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2        200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3        191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4        191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
#
#    reporting_district  part  crime_code  \
# 0                 377     2         624
# 1                 163     2         624
# 2                 155     2         845
# 3                1543     2         745
# 4                1998     2         740
#
#                                    crime_description  modus_operandi  ...  \
# 0                           BATTERY - SIMPLE ASSAULT       0444 0913  ...
# 1                           BATTERY - SIMPLE ASSAULT  0416 1822 1414  ...
# ...

# %%
crime.columns
# Out:
# Index(['division_number', 'date_reported', 'date_occurred', 'area',
#        'area_name', 'reporting_district', 'part', 'crime_code',
#        'crime_description', 'modus_operandi', 'victim_age', 'victim_sex',
#        'victim_descent', 'premise_code', 'premise_description', 'weapon_code',
#        'weapon_description', 'status', 'status_description', 'crime_code_1',
#        'crime_code_2', 'crime_code_3', 'crime_code_4', 'location',
#        'cross_street', 'latitude', 'longitude'],
#       dtype='object')

# %%
crime.dtypes
# Out:
# division_number          int64
# date_reported           object
# date_occurred           object
# area                     int64
# area_name               object
# reporting_district       int64
# part                     int64
# crime_code               int64
# crime_description       object
# modus_operandi          object
# victim_age               int64
# victim_sex              object
# victim_descent          object
# premise_code           float64
# premise_description     object
# weapon_code            float64
# weapon_description      object
# status                  object
# status_description      object
# crime_code_1           float64
# crime_code_2           float64
# crime_code_3           float64
# crime_code_4           float64
# location                object
# cross_street            object
# latitude               float64
# longitude              float64
# dtype: object

# %%
crime.shape
# Out:
# (852950, 27)

# %%
df = crime.drop(labels = ['modus_operandi','weapon_code','weapon_description','crime_code_2','crime_code_3','crime_code_4','cross_street'], axis = 1)

# %%
df
# Out:
#         division_number date_reported        date_occurred  area    area_name  \
# 0              10304468    2020-01-08  2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02  2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14  2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01  2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01  2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                  ...   ...          ...
# 852945        231606525    2023-03-22  2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12  2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02  2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05  2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10  2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df['date_reported']= pd.to_datetime(df['date_reported'], format = '%Y-%m-%d')
df['date_occurred'] = pd.to_datetime(df['date_occurred'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

# %%
df['date_occurred']
# Out:
# 0        2020-01-08 22:30:00
# 1        2020-01-01 03:30:00
# 2        2020-02-13 12:00:00
# 3        2020-01-01 17:30:00
# 4        2020-01-01 04:15:00
#                  ...
# 852945   2023-03-22 10:00:00
# 852946   2023-04-12 16:30:00
# 852947   2023-07-01 00:01:00
# 852948   2023-03-05 09:00:00
# 852949   2023-11-09 23:00:00
# Name: date_occurred, Length: 852950, dtype: datetime64[ns]

# %%
df['date_reported']
# Out:
# 0        2020-01-08
# 1        2020-01-02
# 2        2020-04-14
# 3        2020-01-01
# 4        2020-01-01
#             ...
# 852945   2023-03-22
# 852946   2023-04-12
# 852947   2023-07-02
# 852948   2023-03-05
# 852949   2023-11-10
# Name: date_reported, Length: 852950, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852950 entries, 0 to 852949
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   division_number      852950 non-null  int64
#  1   date_reported        852950 non-null  datetime64[ns]
#  2   date_occurred        852950 non-null  datetime64[ns]
#  3   area                 852950 non-null  int64
#  4   area_name            852950 non-null  object
#  5   reporting_district   852950 non-null  int64
#  6   part                 852950 non-null  int64
#  7   crime_code           852950 non-null  int64
#  8   crime_description    852950 non-null  object
#  9   victim_age           852950 non-null  int64
#  10  victim_sex           740344 non-null  object
#  11  victim_descent       740336 non-null  object
#  12  premise_code         852940 non-null  float64
#  13  premise_description  852432 non-null  object
# ...

# %%
df.describe()
# Out:
#        division_number                  date_reported  \
# count     8.529500e+05                         852950
# mean      2.166969e+08  2022-01-19 08:16:11.356350720
# min       8.170000e+02            2020-01-01 00:00:00
# 25%       2.102184e+08            2021-02-08 00:00:00
# 50%       2.202184e+08            2022-02-11 00:00:00
# 75%       2.301094e+08            2023-01-06 00:00:00
# max       2.399306e+08            2023-12-04 00:00:00
# std       1.100081e+07                            NaN
#
#                        date_occurred           area  reporting_district  \
# count                         852950  852950.000000       852950.000000
# mean   2022-01-09 05:17:37.460835840      10.707354         1117.165490
# min              2020-01-01 00:01:00       1.000000          101.000000
# 25%              2021-01-26 15:00:00       6.000000          615.000000
# 50%              2022-01-30 12:42:00      11.000000         1141.000000
# ...

# %%
df['victim_age'].value_counts()
# Out:
# victim_age
#  0      211842
#  30      19421
#  35      19008
#  31      18603
#  29      18552
#          ...
#  97         63
# -1          60
# -2          13
#  120         1
# -3           1
# Name: count, Length: 103, dtype: int64

# %%
df_age=df[df['victim_age']>0]

# %%
df_age
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# 5             200100501    2020-01-02 2020-01-01 00:30:00     1      Central
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df_age['victim_age'].value_counts()
# Out:
# victim_age
# 30     19421
# 35     19008
# 31     18603
# 29     18552
# 28     18266
#        ...
# 95        89
# 96        88
# 98        67
# 97        63
# 120        1
# Name: count, Length: 99, dtype: int64

# %%
df['year'] = df['date_occurred'].dt.year
df['month'] = df['date_occurred'].dt.month

# %%
df['year']
# Out:
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
#           ...
# 852945    2023
# 852946    2023
# 852947    2023
# 852948    2023
# 852949    2023
# Name: year, Length: 852950, dtype: int32

# %%
df['month']
# Out:
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#           ..
# 852945     3
# 852946     4
# 852947     7
# 852948     3
# 852949    11
# Name: month, Length: 852950, dtype: int32

# %% [markdown]
# # Feature Understanding

# %%
df['month'].value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='month'>

# %%
df['year']=df['year'].value_counts().sort_index().plot(kind = 'bar')

# %%
df=df[~((df['month'] == 12) & (df['year'] == 2023))]

# %%
df
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14 2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df.sort_values(by = 'date_occurred')
# Out:
#         division_number date_reported       date_occurred  area   area_name  \
# 172099        201804089    2020-01-02 2020-01-01 00:01:00    18   Southeast
# 22554         200607915    2020-03-14 2020-01-01 00:01:00     6   Hollywood
# 199268        230604864    2023-01-23 2020-01-01 00:01:00     6   Hollywood
# 198751        230905903    2023-02-20 2020-01-01 00:01:00     9    Van Nuys
# 195340        220512901    2022-08-24 2020-01-01 00:01:00     5      Harbor
# ...                 ...           ...                 ...   ...         ...
# 803457        230125580    2023-12-04 2023-12-04 18:45:00     1     Central
# 664270        230717976    2023-12-04 2023-12-04 19:20:00     7    Wilshire
# 680990        232018745    2023-12-04 2023-12-04 19:36:00    20     Olympic
# 772795        230415044    2023-12-04 2023-12-04 19:45:00     4  Hollenbeck
# 675228        231421222    2023-12-04 2023-12-04 23:00:00    14     Pacific
#
#         reporting_district  part  crime_code  \
# ...

# %%
df.groupby(['year','month']).size().plot().head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df.groupby(['year','month']).size().plot().head(5)
#
# AttributeError: 'Axes' object has no attribute 'head'

# %%
df_age
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# 5             200100501    2020-01-02 2020-01-01 00:30:00     1      Central
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
plt.style.use('seaborn-v0_8-dark-palette')
plt.figure(figsize =(5,6))
plt.hist(df_age['victim_age'],edgecolor = 'black' , color = 'forestgreen', bins = 15)
plt.xlabel('Age')
plt.ylabel('Increased crime')
plt.title('Increased crime as per Age')
plt.tight_layout()

# %%
df['date_occurred_no_time']=df['date_occurred'].dt.date

# %%
crime_count_per_day = df.groupby(['date_occurred_no_time' ,'crime_description']).size()

# %%
Top_20_crime=crime_count_per_day.groupby('crime_description').mean().sort_index().reset_index(name = 'Average_daily_count').sort_values(by = 'Average_daily_count',ascending = False).head(20)

# %%
Top_20_crime
# Out:
#                                      crime_description  Average_daily_count
# 132                                   VEHICLE - STOLEN            63.788703
# 4                             BATTERY - SIMPLE ASSAULT            47.403068
# 115                                  THEFT OF IDENTITY            37.285216
# 21                               BURGLARY FROM VEHICLE            36.688285
# 20                                            BURGLARY            36.235007
# 129  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            36.140865
# 2       ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT            34.083682
# 117                 THEFT PLAIN - PETTY ($950 & UNDER)            30.266388
# 73                   INTIMATE PARTNER - SIMPLE ASSAULT            29.797071
# 113    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)            22.925384
# 112  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...            21.419805
# ...

# %%
plt.barh(Top_20_crime['crime_description'],Top_20_crime['Average_daily_count'])
# Out:
# <BarContainer object of 20 artists>

# %%
plt.figure(figsize= (12,8))
plt.subplot(2,2,1)
crime_plot=df.groupby(['year','month']).size().plot(color= 'green', linewidth=2)
crime_plot.set_xlabel('year - month',fontsize = 10)
crime_plot.set_title('Crime Over Time')
plt.tight_layout()


plt.subplot(2,2,2)
plt.hist(df_age['victim_age'],edgecolor = 'black' , color = 'darkorchid', bins = 15)
plt.xlabel('Age')
plt.ylabel('Increased crime')
plt.title('Increased crime as per Age')
plt.tight_layout()


plt.subplot(2,2,3)
plt.barh(Top_20_crime['crime_description'],Top_20_crime['Average_daily_count'])
plt.xlabel('crime_description')
plt.ylabel('Average_daily_count')
plt.title('Top_20_crime')
plt.tight_layout()

# %%
df['Time to report']= (pd.to_datetime(df['date_reported']) -pd.to_datetime(df['date_occurred_no_time'])).dt.days

# %%
df['Time to report']
# Out:
# 0          0
# 1          1
# 2         61
# 3          0
# 4          0
#           ..
# 852945     0
# 852946     0
# 852947     1
# 852948     0
# 852949     1
# Name: Time to report, Length: 852950, dtype: int64

# %%
df
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14 2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
df['Time to report'].value_counts().head(10)
# Out:
# Time to report
# 0    420653
# 1    185427
# 2     52874
# 3     30942
# 4     19932
# 5     14416
# 6     10837
# 7      9722
# 8      7053
# 9      5660
# Name: count, dtype: int64

# %%
df.groupby(['crime_description'])['Time to report'].mean().sort_values(ascending = False).head(10)
# Out:
# crime_description
# CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)    128.099937
# SEX OFFENDER REGISTRANT OUT OF COMPLIANCE                   123.636782
# SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ    110.913921
# LEWD/LASCIVIOUS ACTS WITH CHILD                              96.076923
# DISHONEST EMPLOYEE ATTEMPTED THEFT                           87.000000
# BIGAMY                                                       66.571429
# SEXUAL PENETRATION W/FOREIGN OBJECT                          66.092946
# ORAL COPULATION                                              62.078616
# EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)                     61.322581
# EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)                   59.640366
# Name: Time to report, dtype: float64

# %%
df_age.groupby('crime_description')['victim_age'].mean().reset_index().sort_values(by = 'victim_age',ascending= False).head(3)
# Out:
#                      crime_description  victim_age
# 45  DISHONEST EMPLOYEE ATTEMPTED THEFT   60.000000
# 12      BLOCKING DOOR INDUCTION CENTER   54.666667
# 77                            LYNCHING   53.000000

# %%
df
# Out:
#         division_number date_reported       date_occurred  area    area_name  \
# 0              10304468    2020-01-08 2020-01-08 22:30:00     3    Southwest
# 1             190101086    2020-01-02 2020-01-01 03:30:00     1      Central
# 2             200110444    2020-04-14 2020-02-13 12:00:00     1      Central
# 3             191501505    2020-01-01 2020-01-01 17:30:00    15  N Hollywood
# 4             191921269    2020-01-01 2020-01-01 04:15:00    19      Mission
# ...                 ...           ...                 ...   ...          ...
# 852945        231606525    2023-03-22 2023-03-22 10:00:00    16     Foothill
# 852946        231210064    2023-04-12 2023-04-12 16:30:00    12  77th Street
# 852947        230115220    2023-07-02 2023-07-01 00:01:00     1      Central
# 852948        230906458    2023-03-05 2023-03-05 09:00:00     9     Van Nuys
# 852949        230319786    2023-11-10 2023-11-09 23:00:00     3    Southwest
#
# ...

# %%
nighttime_crimes=df[(df['date_occurred'].dt.hour>=20) | (df['date_occurred'].dt.hour<=3)]

# %%
df['area_name'].value_counts()
# Out:
# area_name
# Central        57691
# 77th Street    53631
# Pacific        49850
# Southwest      47858
# Hollywood      45018
# Southeast      43357
# Olympic        42979
# Newton         42743
# N Hollywood    42455
# Wilshire       40648
# Rampart        40072
# West LA        39181
# Northeast      36725
# Van Nuys       36070
# West Valley    35851
# Harbor         35104
# Topanga        34755
# Devonshire     34644
# Mission        34011
# Hollenbeck     31932
# Foothill       28375
# Name: count, dtype: int64

# %%
hourly_crime = df['date_occurred'].dt.hour.value_counts().sort_index().reset_index().head(10).sort_values(by = 'date_occurred',ascending = False)

# %%
hourly_crime
# Out:
#    date_occurred  count
# 9              9  30864
# 8              8  31474
# 7              7  22031
# 6              6  19549
# 5              5  14868
# 4              4  16123
# 3              3  19085
# 2              2  21859
# 1              1  25806
# 0              0  35109

# %%
plt.bar(hourly_crime['date_occurred'],hourly_crime['count'])
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Pie Chart with random data

# %%
countries= ['USA', 'Japan', 'Canada', 'Newyork']
profits= [2000, 3000, 9000, 8000]
plt.pie(profits,labels = countries, autopct = '%1.1f%%', explode= [0.2,0,0,0], shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fb3eb4f110>,
# ...
#  [Text(1.2473408625814815, 0.36625233451062955, 'USA'),
#   Text(0.5947048716338131, 0.9253789038307552, 'Japan'),
#   Text(-1.0005952104475537, 0.4569564802357176, 'Canada'),
#   Text(0.4569565739181999, -1.0005951676641962, 'Newyork')],
#  [Text(0.7675943769732192, 0.22538605200654124, '9.1%'),
#   Text(0.32438447543662535, 0.50475212936223, '13.6%'),
#   Text(-0.5457792056986657, 0.2492489892194823, '40.9%'),
#   Text(0.2492490403190181, -0.5457791823622887, '36.4%')])
