# %%
import pandas as pd
import matplotlib.pyplot as plt
world = pd.read_csv('Data for python course/2018-2019+Happiness.csv')
airbnb = pd.read_csv('Data for python course/airbnb.csv')
salaries = pd.read_csv('Data for python course/salaries.csv')
sales = pd.read_csv('Data for python course/web_sales.csv')
eth = pd.read_csv('Data for python course/Ethereum+Historical+Data.csv')

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
plt.plot(eth.index,eth['Price'])

# %%
plt.plot(eth.index,eth['Price'])
plt.xlabel('Date')
plt.ylabel('Price')
plt.title(' Ethereum price chart')
plt.xticks(rotation = 45)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200., 1400.,
#         1600.]),
#  [Text(-200.0, 0, '−200'),
#   Text(0.0, 0, '0'),
#   Text(200.0, 0, '200'),
#   Text(400.0, 0, '400'),
#   Text(600.0, 0, '600'),
#   Text(800.0, 0, '800'),
#   Text(1000.0, 0, '1000'),
#   Text(1200.0, 0, '1200'),
#   Text(1400.0, 0, '1400'),
#   Text(1600.0, 0, '1600')])

# %%
plt.figure(figsize = (4,3), dpi = 120)
plt.plot(eth.index,eth['Price'], eth['High'], color = 'red')
plt.xlabel('Date')
plt.ylabel('High')
plt.title(' Ethereum price chart')
plt.xticks(rotation = 45)
# Out:
# (array([-250.,    0.,  250.,  500.,  750., 1000., 1250., 1500., 1750.]),
#  [Text(-250.0, 0, '−250'),
#   Text(0.0, 0, '0'),
#   Text(250.0, 0, '250'),
#   Text(500.0, 0, '500'),
#   Text(750.0, 0, '750'),
#   Text(1000.0, 0, '1000'),
#   Text(1250.0, 0, '1250'),
#   Text(1500.0, 0, '1500'),
#   Text(1750.0, 0, '1750')])

# %%
plt.figure(figsize = (8,3), dpi = 120)
plt.subplot(1,3,1)
plt.plot(eth.index,eth['Price'], eth['High'], color = 'blue')
plt.xlabel('Date')
plt.ylabel('High')
plt.title(' Ethereum price chart')
plt.xticks(rotation = 45)


plt.subplot(1,3,2)
plt.plot(eth.index,eth['Price'], eth['High'], color = 'red')
plt.xlabel('Date')
plt.ylabel('High')
plt.title(' Ethereum price chart')
plt.xticks(rotation = 45)


plt.subplot(1,3,3)
plt.plot(eth.index,eth['Price'], eth['High'], color = 'green')
plt.xlabel('Date')
plt.ylabel('High')
plt.title(' Ethereum price chart')
plt.xticks(rotation = 45)
# Out:
# (array([-500.,    0.,  500., 1000., 1500., 2000.]),
#  [Text(-500.0, 0, '−500'),
#   Text(0.0, 0, '0'),
#   Text(500.0, 0, '500'),
#   Text(1000.0, 0, '1000'),
#   Text(1500.0, 0, '1500'),
#   Text(2000.0, 0, '2000')])

# %%
sales.head(5)
# Out:
#    ProductKey                  product product_subcategory  OrderDateKey  \
# 0         310         Road-150 Red, 62          Road Bikes      20101229
# 1         346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2         346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3         336       Road-650 Black, 62          Road Bikes      20101229
# 4         346  Mountain-100 Silver, 44      Mountain Bikes      20101229
#
#    CalendarYear SalesTerritoryRegion SalesTerritoryCountry SalesOrderNumber  \
# 0          2010               Canada                Canada          SO43697
# 1          2010               France                France          SO43698
# 2          2010            Northwest         United States          SO43699
# 3          2010            Southwest         United States          SO43700
# 4          2010            Australia             Australia          SO43701
#
#    SalesAmount    TaxAmt  Freight
# 0    3578.2700  286.2616  89.4568
# 1    3399.9900  271.9992  84.9998
# 2    3399.9900  271.9992  84.9998
# 3     699.0982   55.9279  17.4775
# 4    3399.9900  271.9992  84.9998

# %%
sales['product_subcategory'].unique()
# Out:
# array(['Road Bikes', 'Mountain Bikes', 'Bottles and Cages',
#        'Touring Bikes', 'Helmets', 'Tires and Tubes', 'Bike Stands',
#        'Jerseys', 'Gloves', 'Fenders', 'Caps', 'Socks', 'Hydration Packs',
#        'Vests', 'Cleaners', 'Bike Racks', 'Shorts'], dtype=object)

# %%
bike_sales=sales[sales['product_subcategory'].isin(['Road Bikes','Mountain Bikes','Touring Bikes'])]

# %%
bike_sales_grp=bike_sales.groupby('product_subcategory')['SalesAmount'].sum().reset_index()

# %%
accessory_sales= sales[~sales['product_subcategory'].isin(['Road Bikes','Mountain Bikes','Touring Bikes'])]

# %%
accessory_sales_grp =accessory_sales.groupby('product_subcategory')['SalesAmount'].sum().reset_index().sort_values(by = 'SalesAmount', ascending = False)

# %%
accessory_sales_grp
# Out:
#    product_subcategory  SalesAmount
# 12     Tires and Tubes    245529.32
# 7              Helmets    225335.60
# 9              Jerseys    172950.68
# 10              Shorts     71319.81
# 2    Bottles and Cages     56798.19
# 5              Fenders     46619.58
# 8      Hydration Packs     40307.67
# 1          Bike Stands     39591.00
# 0           Bike Racks     39360.00
# 13               Vests     35687.00
# 6               Gloves     35020.70
# 3                 Caps     19688.10
# 4             Cleaners      7218.60
# 11               Socks      5106.32

# %%
bike_sales_grp
# Out:
#   product_subcategory   SalesAmount
# 0      Mountain Bikes  9.952760e+06
# 1          Road Bikes  1.452058e+07
# 2       Touring Bikes  3.844801e+06

# %%
plt.pie(bike_sales_grp['SalesAmount'], labels =bike_sales_grp['product_subcategory'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1cba2384f80>,
#   <matplotlib.patches.Wedge at 0x1cba3be6870>,
#   <matplotlib.patches.Wedge at 0x1cba3c29e80>],
#  [Text(0.4948817174501019, 0.982391004505659, 'Mountain Bikes'),
#   Text(-0.8569791039026488, -0.6896280268914636, 'Road Bikes'),
#   Text(1.0014433493330255, -0.45509473527679034, 'Touring Bikes')])

# %%
plt.barh(accessory_sales_grp['product_subcategory'],accessory_sales_grp['SalesAmount'])
# Out:
# <BarContainer object of 14 artists>

# %%
sales['OrderDate']= pd.to_datetime(sales['OrderDateKey'], format = '%Y%m%d')
sales['monthYear']=pd.to_datetime(sales['OrderDate'].dt.strftime('%Y-%m'))

# %%
monthly_sales=sales.groupby('monthYear')['SalesAmount'].sum().reset_index()
daily_sales=sales.groupby('OrderDate')['SalesAmount'].sum().reset_index()

# %%
plt.plot(monthly_sales['monthYear'],monthly_sales['SalesAmount'])

# %%
plt.plot(daily_sales['OrderDate'],daily_sales['SalesAmount'])

# %%
country_sales=sales.groupby('SalesTerritoryCountry')['SalesAmount'].sum().reset_index().sort_values(by = 'SalesAmount' , ascending = False)

# %%
plt.bar(country_sales['SalesTerritoryCountry'],country_sales['SalesAmount'])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-dark-palette')
plt.figure(figsize=(12,8), dpi =120)
plt.subplot(2,2,1)
plt.plot(monthly_sales['monthYear'],monthly_sales['SalesAmount'])
plt.xticks(rotation = 45)

plt.subplot(2,2,2)
plt.barh(accessory_sales_grp['product_subcategory'],accessory_sales_grp['SalesAmount'])

plt.subplot(2,2,3)
plt.pie(bike_sales_grp['SalesAmount'], labels =bike_sales_grp['product_subcategory'],autopct= '%1.1f%%', colors= ['rebeccapurple','teal','maroon'],explode=[0.3,0,0], shadow = True)

plt.subplot(2,2,4)
plt.bar(country_sales['SalesTerritoryCountry'],country_sales['SalesAmount'], edgecolor='red', color= 'orange')
plt.tight_layout()
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'United States'),
#   Text(1, 0, 'Australia'),
#   Text(2, 0, 'United Kingdom'),
#   Text(3, 0, 'Germany'),
#   Text(4, 0, 'France'),
#   Text(5, 0, 'Canada')])
