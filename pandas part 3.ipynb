# %%
import pandas as pd
import matplotlib as plt

# %%
world = pd.read_csv('Data for python course/2018-2019+Happiness.csv')
airbnb = pd.read_csv('Data for python course/airbnb.csv')
salaries = pd.read_csv('Data for python course/salaries.csv')
sales = pd.read_csv('Data for python course/web_sales.csv')
eth = pd.read_csv('Data for python course/Ethereum+Historical+Data.csv')

# %%
eth.sort_index()
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30344 non-null  float64
#  8   Beds                        30393 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  int64
#  12  Review Scores Rating        22155 non-null  float64
# ...

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
airbnb['Host Since'] = pd.to_datetime(airbnb['Host Since'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14544\4085603669.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   airbnb['Host Since'] = pd.to_datetime(airbnb['Host Since'])

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  datetime64[ns]
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30344 non-null  float64
#  8   Beds                        30393 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  int64
#  12  Review Scores Rating        22155 non-null  float64
# ...

# %%
airbnb.sort_values(by = ['Host Since'])
# Out:
#         Host Id Host Since                                 Name Neighbourhood  \
# 3           500 2008-06-26   Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500 2008-06-26             Trendy Times Square Loft     Manhattan
# 5          1039 2008-07-25   Big Greenpoint 1BD w/ Skyline View      Brooklyn
# 6          1783 2008-08-12                         Amazing Also     Manhattan
# 7          2078 2008-08-15  Colorful, quiet, & near the subway!      Brooklyn
# ...         ...        ...                                  ...           ...
# 30469  43018396 2015-08-31   Cute East Village Studio Sept 8-16     Manhattan
# 30477  42999189 2015-08-31     Huge Beautiful Bedroom - Astoria        Queens
# 0       5162530        NaT      1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899        NaT      Sunny, Private room in Bushwick      Brooklyn
# 2      39608626        NaT                 Sunny Room in Harlem     Manhattan
#
# ...

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth['Change %']= eth['Change %'] . replace ('%' , '', regex = True)

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K     0.89
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K     2.76
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K    -0.21
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K     2.19
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K     3.08
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M     0.94
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M     0.04
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M     5.56
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M    -2.72
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M     1.19
#
# [1502 rows x 8 columns]

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K     0.89
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K     2.76
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K    -0.21
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K     2.19
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K     3.08
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M     0.94
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M     0.04
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M     5.56
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M    -2.72
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M     1.19
#
# [1502 rows x 8 columns]

# %%
eth['Change %'] = eth['Change %'] .astype('float')

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol.  Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K      0.89
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K      2.76
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K     -0.21
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K      2.19
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K      3.08
# ...          ...  ...      ...      ...      ...      ...      ...       ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M      0.94
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M      0.04
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M      5.56
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M     -2.72
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M      1.19
#
# [1502 rows x 8 columns]

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1502 non-null   object
#  1   Coin      1502 non-null   object
#  2   Price     1502 non-null   float64
#  3   Open      1502 non-null   float64
#  4   High      1502 non-null   float64
#  5   Low       1502 non-null   float64
#  6   Vol.      1502 non-null   object
#  7   Change %  1502 non-null   float64
# dtypes: float64(5), object(3)
# memory usage: 94.0+ KB

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
salaries.groupby('job_title')['salary_in_usd'].mean()
# Out:
# job_title
# AI Architect                       250328.000000
# AI Developer                       139916.705882
# AI Engineer                        175116.225806
# AI Programmer                       67382.333333
# AI Research Engineer                63481.600000
#                                        ...
# Sales Data Analyst                  60000.000000
# Software Data Engineer             111627.666667
# Staff Data Analyst                  79917.000000
# Staff Data Scientist               134500.000000
# Staff Machine Learning Engineer    185000.000000
# Name: salary_in_usd, Length: 124, dtype: float64

# %%
salaries.groupby('job_title')['salary_in_usd'].agg(['mean','max','min']).sort_values(by = 'mean', ascending = False)
# Out:
#                                         mean     max     min
# job_title
# Business Intelligence Consultant  615201.000  615201  615201
# Analytics Engineering Manager     399880.000  399880  399880
# Data Science Tech Lead            375000.000  375000  375000
# Managing Director Data Science    300000.000  300000  300000
# AWS Data Architect                258000.000  258000  258000
# ...                                      ...     ...     ...
# Machine Learning Specialist        55000.000   70000   40000
# Data DevOps Engineer               53984.000   53984   53984
# Insight Analyst                    47673.875   53984   43064
# Compliance Data Analyst            45000.000   60000   30000
# Principal Data Architect           38154.000   38154   38154
#
# [124 rows x 3 columns]

# %%
salaries.groupby('job_title').agg({'salary_in_usd':['mean', 'max', 'min'],'remote_ratio':['mean','max','min']})
# Out:
#                                  salary_in_usd                 remote_ratio  \
#                                           mean     max     min         mean
# job_title
# AI Architect                     250328.000000  330000  146900    33.333333
# AI Developer                     139916.705882  275000   50000    41.176471
# AI Engineer                      175116.225806  372000   21593    30.645161
# AI Programmer                     67382.333333  120000   40000    50.000000
# AI Research Engineer              63481.600000  150000   24322    80.000000
# ...                                        ...     ...     ...          ...
# Sales Data Analyst                60000.000000   60000   60000     0.000000
# Software Data Engineer           111627.666667  210000   50000    83.333333
# Staff Data Analyst                79917.000000  179998   15000    50.000000
# Staff Data Scientist             134500.000000  164000  105000    75.000000
# ...

# %%
salaries.groupby(['work_year', 'experience_level'])['salary_in_usd'].mean().unstack()
# Out:
# experience_level            EN             EX             MI             SE
# work_year
# 2020              69840.666667  179958.250000   91870.935484  138648.894737
# 2021              63463.065217  186128.000000   86818.390805  125989.746667
# 2022              80018.698276  188260.292683  102733.432961  148059.962148
# 2023              96016.143860  189511.070093  120579.427548  165579.532707

# %%
work_year_avg_experience = salaries.groupby(['work_year', 'experience_level'])['salary_in_usd'].mean().unstack()

# %%
work_year_avg_experience.plot(kind='bar')
# Out:
# <Axes: xlabel='work_year'>

# %%
salaries.groupby(['job_title','experience_level']).agg({'salary_in_usd': ['mean','max'] , 'remote_ratio' : ['max','mean']})
# Out:
#                                                   salary_in_usd          \
#                                                            mean     max
# job_title                       experience_level
# AI Architect                    EX                215936.000000  215936
#                                 SE                253454.545455  330000
# AI Developer                    EN                110119.500000  215936
#                                 MI                138294.333333  200000
#                                 SE                162873.000000  275000
# ...                                                         ...     ...
# Staff Data Analyst              EN                 44753.000000   44753
#                                 EX                 15000.000000   15000
#                                 MI                179998.000000  179998
# Staff Data Scientist            SE                134500.000000  164000
# ...
